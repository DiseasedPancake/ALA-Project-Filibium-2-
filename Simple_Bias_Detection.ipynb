# %% [markdown]
# <a href="https://colab.research.google.com/github/DiseasedPancake/ALA-Project-Filibium-2-/blob/main/Simple_Bias_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
loan_data = [
    {"age": 30, "income": 5000, "loan_approved": False},
    {"age": 30, "income": 10000, "loan_approved": False},
    {"age": 30, "income": 20000, "loan_approved": False},
    {"age": 30, "income": 30000, "loan_approved": False},
    {"age": 30, "income": 50000, "loan_approved": True},
    {"age": 30, "income": 60000, "loan_approved": True},
    {"age": 30, "income": 70000, "loan_approved": True},
    {"age": 25, "income": 5000, "loan_approved": False},
    {"age": 25, "income": 10000, "loan_approved": False},
    {"age": 25, "income": 20000, "loan_approved": False},
    {"age": 25, "income": 30000, "loan_approved": False},
    {"age": 25, "income": 50000, "loan_approved": False},
    {"age": 25, "income": 60000, "loan_approved": False},
    {"age": 25, "income": 70000, "loan_approved": False},
    {"age": 35, "income": 10000, "loan_approved": False},
    {"age": 35, "income": 20000, "loan_approved": False},
    {"age": 35, "income": 30000, "loan_approved": False},
    {"age": 35, "income": 40000, "loan_approved": False},
    {"age": 40, "income": 70000, "loan_approved": True},
    {"age": 50, "income": 80000, "loan_approved": True},
    {"age": 50, "income": 60000, "loan_approved": True},
    {"age": 50, "income": 50000, "loan_approved": True},
    {"age": 50, "income": 40000, "loan_approved": False},
]

# %%
loan_data = pd.DataFrame(loan_data)

# %%
datam= loan_data.groupby(["age"])["loan_approved"].value_counts(normalize=True).unstack()

# %%
datam.fillna(0, inplace=True)
datam
# Out:
# loan_approved     False     True
# age
# 25             1.000000  0.000000
# 30             0.571429  0.428571
# 35             1.000000  0.000000
# 40             0.000000  1.000000
# 50             0.250000  0.750000

# %%
datagrouploan= loan_data.groupby(["age"])["loan_approved"].value_counts(normalize=False).unstack()
datagrouploan.fillna(0, inplace=True)

# %%
datagrouploan
# Out:
# loan_approved  False  True
# age
# 25               7.0    0.0
# 30               4.0    3.0
# 35               4.0    0.0
# 40               0.0    1.0
# 50               1.0    3.0

# %%
datagroup= loan_data.groupby(["age","income"])["loan_approved"].all().unstack()

# %%
datagroup.fillna('_', inplace=True)

# %%
datagroup
# Out:
# income  5000   10000  20000  30000  40000  50000  60000  70000 80000
# age
# 25      False  False  False  False      _  False  False  False     _
# 30      False  False  False  False      _   True   True   True     _
# 35          _  False  False  False  False      _      _      _     _
# 40          _      _      _      _      _      _      _   True     _
# 50          _      _      _      _  False   True   True      _  True
